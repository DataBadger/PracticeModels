# %%
import pandas as pd 
import numpy as np 
import seaborn as sb

# %%
df = pd.read_csv('C:\\Users\\Sasha\\Desktop\\Py\\Git\\PracticeModels\\DataAnalysis\\repl2.csv', index_col='date',parse_dates=['date'])

# %%
df.head()
# Out:
#             value
# date
# 2016-09-05   1201
# 2016-10-05   2329
# 2016-11-05   1716
# 2016-12-05  10539
# 2016-05-13   6933

# %%
df = df[(df['value'] >= df['value'].quantile(0.025)) & (df['value'] <= df['value'].quantile(0.975))]

# %%
df.plot(ylim=(0,180000),kind='line', y='value', figsize=(18,6))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df['year'] = df.index.year
df['month'] = df.index.month
df.head()
# Out:
#             value  year  month
# date
# 2016-05-19  19736  2016      5
# 2016-05-26  18060  2016      5
# 2016-05-27  19997  2016      5
# 2016-05-28  19044  2016      5
# 2016-05-29  20325  2016      5

# %%
df_bar = df.groupby(['year','month'])['value']
# Out:
# date
# 2016-05-19    19736
# 2016-05-26    18060
# 2016-05-27    19997
# 2016-05-28    19044
# 2016-05-29    20325
#               ...
# 2019-08-05    92181
# 2019-09-05    91506
# 2019-10-05    86823
# 2019-11-05    89641
# 2019-12-05    65338
# Name: value, Length: 240, dtype: int64

# %%
df_bar = df_bar.unstack()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-0c89fbbb498f> in <module>
# ----> 1 df_bar = df_bar.unstack()
#
# C:\Program Files\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'unstack'
